# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv("C:\\Users\\srush\\OneDrive\\Desktop\\AIML Internship\\AIML-Internship\\Day 11\\data_visualization.csv")
data
# Out:
#     Unnamed: 0  Student_ID     Name  Gender Department  Age  Math_Score  \
# 0            0           1    Aarav    Male         CS   21          78
# 1            1           2     Diya  Female         IT   22          85
# 2            2           3    Rohan    Male         CS   20          90
# 3            3           4    Sneha  Female        ECE   21          67
# 4            4           5    Arjun    Male         IT   23          88
# 5            5           6    Meera  Female        ECE   22          76
# 6            6           7    Kiran    Male         CS   21          92
# 7            7           8   Ananya  Female         IT   20          81
# 8            8           9    Rahul    Male        ECE   22          74
# 9            9          10     Isha  Female         CS   23          89
# 10          10          11   Vikram    Male         IT   21          84
# 11          11          12    Pooja  Female         CS   20          91
# ...

# %%
plt.figure()
sns.pairplot(data)
plt.show()

# %%
plt.plot(data.Math_Score,Color="green")
plt.grid()
plt.title("Line Plot1")
plt.xlabel("Math_Score")
plt.ylabel("Time Series")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.plot(data.Math_Score,Color="green")
#       2 plt.grid()
#       3 plt.title("Line Plot1")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
# ...
