# %%
import pandas as pd
import numpy as np

# %%
products=pd.Series([700,150,300], index=["Laptop", "Mouse", "Keyboard"])
products
# Out:
# Laptop      700
# Mouse       150
# Keyboard    300
# dtype: int64

# %%
products.loc["Laptop"]
# Out:
# np.int64(700)

# %%
products.iloc[0:2]
# Out:
# Laptop    700
# Mouse     150
# dtype: int64

# %%
products
# Out:
# Laptop      700
# Mouse       150
# Keyboard    300
# dtype: int64
