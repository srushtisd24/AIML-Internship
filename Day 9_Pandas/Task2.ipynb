# %%
import pandas as pd
import numpy as np

# %%
Grade=pd.Series([85,np.nan,92,45,np.nan,78,55])
Grade
# Out:
# 0    85.0
# 1     NaN
# 2    92.0
# 3    45.0
# 4     NaN
# 5    78.0
# 6    55.0
# dtype: float64
