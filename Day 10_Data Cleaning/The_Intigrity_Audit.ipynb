# %%
import pandas as pd
import numpy as np

df = pd.read_csv("C:\\Users\\srush\\OneDrive\\Desktop\\AIML Internship\\AIML-Internship\\Day 10_Data Cleaning\\Customers_Orders.csv")

print("Shape BEFORE cleaning:", df.shape)

print("\nMissing Values:\n", df.isna().sum())

numeric_cols = df.select_dtypes(include="number").columns

for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())

df = df.drop_duplicates()

print("\nShape AFTER cleaning:", df.shape)
print("\nCleaned Data:\n", df)
# Out:
# Shape BEFORE cleaning: (5, 4)
#
# Missing Values:
#      Order_ID     1
# Customer_Name    0
# Amount           1
# Quantity         1
# dtype: int64
#
# Shape AFTER cleaning: (4, 4)
#
# Cleaned Data:
#         Order_ID Customer_Name  Amount  Quantity
# 1         101.0         Alice   250.0       2.0
# 1         102.0           Bob   375.0       1.0
# 2         103.0       Charlie   300.0       3.5
# 3         104.0         David   450.0       5.0
